# %%
pip install vaderSentiment textstat nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: vaderSentiment in /Users/moritz/Library/Python/3.9/lib/python/site-packages (3.3.2)
# Requirement already satisfied: textstat in /Users/moritz/Library/Python/3.9/lib/python/site-packages (0.7.4)
# Requirement already satisfied: nltk in /Users/moritz/Library/Python/3.9/lib/python/site-packages (3.9.1)
# Requirement already satisfied: requests in /Users/moritz/Library/Python/3.9/lib/python/site-packages (from vaderSentiment) (2.32.3)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from textstat) (58.0.4)
# Requirement already satisfied: pyphen in /Users/moritz/Library/Python/3.9/lib/python/site-packages (from textstat) (0.17.0)
# Requirement already satisfied: joblib in /Users/moritz/Library/Python/3.9/lib/python/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: click in /Users/moritz/Library/Python/3.9/lib/python/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: tqdm in /Users/moritz/Library/Python/3.9/lib/python/site-packages (from nltk) (4.67.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/moritz/Library/Python/3.9/lib/python/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/moritz/Library/Python/3.9/lib/python/site-packages (from requests->vaderSentiment) (2024.8.30)
# Requirement already satisfied: idna<4,>=2.5 in /Users/moritz/Library/Python/3.9/lib/python/site-packages (from requests->vaderSentiment) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/moritz/Library/Python/3.9/lib/python/site-packages (from requests->vaderSentiment) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/moritz/Library/Python/3.9/lib/python/site-packages (from requests->vaderSentiment) (2.2.3)
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import math
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import textstat

# %%
df=pd.read_csv("quotes.csv")

# %%
df.head()
# Out:
#                                            quotetext character  \
# 0  Behind every exquisite thing that existed, the...       NaN
# 1  Children begin by loving their parents; as the...       NaN
# 2  Every portrait that is painted with feeling is...       NaN
# 3  Experience is merely the name men gave to thei...       NaN
# 4  Mere words! How terrible they were! One could ...       NaN
#
#                            title          author  year
# 0   "The Picture of Dorian Gray"   "Oscar Wilde"  1890
# 1   "The Picture of Dorian Gray"   "Oscar Wilde"  1890
# 2   "The Picture of Dorian Gray"   "Oscar Wilde"  1890
# 3   "The Picture of Dorian Gray"   "Oscar Wilde"  1890
# 4   "The Picture of Dorian Gray"   "Oscar Wilde"  1890

# %%
import time

start_time = time.time()

# %% [markdown]
# ### Extract Metadata

# %% [markdown]
# #### Numeric Features

# %%
df['quotelength'] = df['quotetext'].apply(lambda x: len(x))
df['quote_words'] = df['quotetext'].apply(lambda x: len(x.split()))
df['quote_sentences'] = df['quotetext'].apply(lambda x: x.count('.')+x.count('?')+x.count('!'))

# %%
df["characterlength"] = df["character"].fillna("").apply(lambda x: len(x))
df["character_words"] = df["character"].fillna("").apply(lambda x: len(x.split()))

# %%
df["quote_exclemation"] = df["quotetext"].apply(lambda x: x.count('!'))
df["quote_question"] = df["quotetext"].apply(lambda x: x.count('?'))

# %%
df.sample(6)
# Out:
#                                               quotetext     character  \
# 1506  Oh! do not attack me with your watch. A watch ...           NaN
# 2319  Experience is what you get when you didn't get...  Randy Pausch
# 1132   Yet so vain is man, and so blinded by his vanity           NaN
# 3051  It is nothing to die; it is dreadful not to live.           NaN
# 1617  When however small a measure of jealousy is mi...           NaN
# 944   One uses power by grasping it lightly. To gras...           NaN
#
#                         title         author  year  quotelength  quote_words  \
# 1506           Mansfield Park    Jane Austen  1814          113           25
# 2319         The Last Lecture   Randy Pausch  2008          130           24
# 1132    The War of the Worlds     H.G. Wells  1897           48           11
# 3051           Les Misérables    Victor Hugo  1862           49           11
# 1617  A Prayer for Owen Meany    John Irving  1989          109           18
# 944          Children of Dune  Frank Herbert  1976          121           24
#
#       quote_sentences  characterlength  character_words  quote_exclemation  \
# 1506                4                0                0                  1
# 2319                2               12                2                  0
# 1132                0                0                0                  0
# 3051                1                0                0                  0
# 1617                1                0                0                  0
# 944                 2                0                0                  0
#
#       quote_question
# 1506               0
# 2319               0
# 1132               0
# 3051               0
# 1617               0
# 944                0

# %% [markdown]
# Sentiment analysis

# %%
analyzer = SentimentIntensityAnalyzer()

# Function to get sentiment compound score
def get_sentiment_compound(text):
    score = analyzer.polarity_scores(text)
    return score['compound']

# Apply the function to each row
df['sentiment_compound'] = df['quotetext'].apply(get_sentiment_compound)

df.sample()
# Out:
#         quotetext character                title         author  year  \
# 1788  So it goes.       NaN  Slaughterhouse-Five  Kurt Vonnegut  1969
#
#       quotelength  quote_words  quote_sentences  characterlength  \
# 1788           11            3                1                0
#
#       character_words  quote_exclemation  quote_question  sentiment_compound
# 1788                0                  0               0                 0.0

# %% [markdown]
# Flesch reading ease

# %%
df['readability_score'] = df['quotetext'].apply(textstat.flesch_reading_ease)

# %%
def lexical_diversity(text):
    words = text.split()
    return len(set(words)) / len(words) if words else 0


df['lexical_diversity'] = df['quotetext'].apply(lexical_diversity)

# %%
df.sample(6)
# Out:
#                                               quotetext character  \
# 372   Where there is no experience the wise man is s...       NaN
# 2475  Sometimes, on a very clear night, if I is swig...       BFG
# 5                The basis of optimism is sheer terror.       NaN
# 2512  If I am the chief of sinners, I am the chief o...       NaN
# 1146  Great poetry, whether written in Greek or in E...       NaN
# 1684  He is taller by almost the breadth of my nail,...  Gulliver
#
#                                                   title  \
# 372   Dreams from My Father: A Story of Race and Inh...
# 2475                                            The BFG
# 5                          "The Picture of Dorian Gray"
# 2512        The Strange Case of Dr. Jekyll and Mr. Hyde
# 1146                               The Story of My Life
# 1684                                 Gulliver's Travels
#
#                       author  year  quotelength  quote_words  quote_sentences  \
# 372             Barack Obama  1995           52           10                1
# 2475              Roald Dahl  1982          154           29                1
# 5              "Oscar Wilde"  1890           38            7                1
# 2512  Robert Louis Stevenson  1886           63           14                1
# 1146            Helen Keller   NaN          105           17                1
# 1684          Jonathan Swift  1726          128           26                1
#
#       characterlength  character_words  quote_exclemation  quote_question  \
# 372                 0                0                  0               0
# 2475                3                1                  0               0
# 5                   0                0                  0               0
# 2512                0                0                  0               0
# 1146                0                0                  0               0
# 1684                8                1                  0               0
#
#       sentiment_compound  readability_score  lexical_diversity
# 372               0.2263              86.71           0.900000
# 2475              0.4391              67.42           0.827586
# 5                 0.0258              64.37           1.000000
# 2512             -0.5267              82.65           0.642857
# 1146              0.8625              62.68           0.941176
# 1684             -0.3612              78.93           0.884615

# %%
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Elapsed time: 0.4616219997406006 seconds

# %%
df.to_csv("quotes_with_features.csv", index=False)
